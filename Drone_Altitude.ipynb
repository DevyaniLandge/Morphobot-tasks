# %% [markdown]
# <a href="https://colab.research.google.com/github/DevyaniLandge/Morphobot-tasks/blob/Tasks_Devyani/Drone_Altitude.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
import math

# %%
u_t=0
t=0
prev_er=0
inte=0
H_set=10
k_p=5
k_i=5
k_d=0.1
alt=[]
thr=[]
time=[]
er_arr=[]

# %%
while((t<500)and(u_t>=0)):
  H=2-(0.002*t)+(0.03*(u_t))
  er=H_set-H
  inte+=er*0.1
  dev=(er-prev_er)/0.1
  prev_er=er
  P=k_p*er
  I=k_i*inte
  D=k_d*dev
  u_t=P+I+D
  thr.append(round(u_t,3))
  alt.append(round(H,3))
  time.append(t)
  t+=0.1
  er_arr.append(round(er,3))

# %%
thr=np.array(thr)
alt=np.array(alt)
time=np.array(time)
#print(level)
#print(len(level))
er_arr=np.array(er_arr)
plt.plot(time,alt)

plt.axhline(H_set, linestyle="--", label="Desired Alt")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Altitude")
plt.show()

# %%
plt.plot(time,thr)
plt.xlabel("Time")
plt.ylabel("Throttle")
plt.show()

# %%
plt.plot(time,er_arr)
plt.xlabel("Time")
plt.ylabel("Error")
plt.show()
